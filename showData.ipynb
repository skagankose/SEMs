# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import gzip as gz

from IPython.display import display

# %%
dataSet = 'dataSet.gz'
keyphraseSet = 'keyphraseSet.txt'

# %%
# Read datas
dt = pd.read_table(gz.open(dataSet))
dt_keyphrase = pd.read_csv(keyphraseSet)

# Rename columns 
dt.columns = ['day', 'account_id', 'rank', 'keyphrase', 'avg_bid', 'impression', 'clicks']
dt_keyphrase.columns = ['keys']

# Shuffle dataSet
dt = dt.iloc[np.random.permutation(len(dt))]

# %%
for index,row in dt.head(77850271).iterrows():
    
    if int(row['clicks']) >= int(row['impression']) + 2:
        
        print(row)
        print('___________________________________')
        
    # if row['clicks'] >= min_clicks_test and row['impression'] >= min_impression_test:
# Out:
# day                                                          98
# account_id                 5c9aa1f2-1c09-418e-b79b-836e50e3eb09
# rank                                                          4
# keyphrase     3db691494440189b f5bdd24f09cd10a8 c2d70f792220...
# avg_bid                                                     550
# impression                                                    1
# clicks                                                        3
# Name: 25093589, dtype: object
# ___________________________________
# day                                                          72
# account_id                 435827a8-a507-4c19-9e31-7426024522b7
# rank                                                          1
# keyphrase     af7a76499f431c91 70a7ddddc4ade31e 79021a2e2c83...
# avg_bid                                                     200
# impression                                                    1
# clicks                                                        3
# ...

# %%
display(dt.head(10))
# Out:
#           day                            account_id  rank  \
# 66725564   14  108d9712-83b2-4314-8d32-eac8f8231242    14
# 52450412   71  282ca598-2fcb-4c55-9ff4-3aaab9fbee5c     7
# 21809029   37  c62a181f-4cee-447c-9291-bd2fc20ef497    19
# 43723942    4  1c531bae-7e65-40e8-a296-d11856344035     4
# 58862060  123  40fe4ff0-201d-41ff-9c19-a105e2ce2350    12
# 10010079   96  bf49b318-dfbf-4226-b0f9-bd839e02106c     4
# 40591285  113  adfc8e8d-4161-43e1-8eb5-72e2460abb4f     5
# 74265984  123  1080f156-9250-438d-be22-46f1d49827b2     5
# 3887408    67  d9d7f9cd-9674-4c8c-b312-a342e473eeb6     5
# 49072228  121  af5451d2-3e0f-4ae2-8bee-9d164c628955     3
#
#                                                   keyphrase  avg_bid  \
# 66725564  aef4ee042bea9c6b 5b9834ef1db9cdf7 fc4f04e28774...     2000
# 52450412                  3db691494440189b 95718c051dae97ec      290
# 21809029                  ac26bfe54a8a8f38 3db691494440189b     1250
# ...

# %%
display(dt_keyphrase)
# Out:
#                    keys
# 0      1001140e40fff9fd
# 1      10024382a4ae7a07
# 2      1002d06dcd20f283
# 3      1003306ca93ebfee
# 4      1004a8c8af63bb5b
# 5      1005df05ad84f962
# 6      10068f9fe94d0f16
# 7      1006a4984b65f5e5
# 8      1006f25cb0122400
# 9      1006fe0534f616c9
# 10     100752226da94f8a
# 11     1008b6594d0930d8
# 12     1009e6d758abbd11
# 13     100aad48ff6522b5
# 14     100ac8b36e0fd037
# 15     100aff8b136d865a
# 16     100b1cfbdf08ffdc
# 17     100c88088924ed6a
# 18     100e059c905ad24e
# 19     100e12ed2a2712d7
# 20     100e524b01ab76be
# 21     100e750337bc5b64
# 22     100f40c85629e8ba
# 23     1010532ee989f0a0
# 24     101172a5bc384e0f
# 25     10126155001c2902
# 26     1012f9ae41403dc5
# 27     1013039a3fc8bdf9
# 28     10133c24c5fa8e64
# 29     1013e2a7e83ebe57
# ...                 ...
# 75328  ffe637cf46e97622
# 75329  ffe697c08de8eb66
# 75330  ffe73a2d5906da4e
# 75331  ffe75cc854770bd9
# 75332  ffe842eea5eb3966
# 75333  ffe864a02a1edcec
# ...
